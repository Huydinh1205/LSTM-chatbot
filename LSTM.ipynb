# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np

# %%
import json
import itertools

with open("data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

pairs = []

for intent in data["intents"]:
    patterns = intent["patterns"]
    responses = intent["responses"]
    # Chọn 1 response ngẫu nhiên cho mỗi pattern (cũng có thể kết hợp tất cả)
    for p in patterns:
        for r in responses:  # hoặc chỉ r = random.choice(responses)
            pairs.append((p, r))

print(f"Total pairs: {len(pairs)}")
print(pairs[:10])
# Out:
# Total pairs: 528
# [('Hi', 'Hello!'), ('Hi', 'Good to see you again!'), ('Hi', 'Hi there, how can I help?'), ('How are you?', 'Hello!'), ('How are you?', 'Good to see you again!'), ('How are you?', 'Hi there, how can I help?'), ('Is anyone there?', 'Hello!'), ('Is anyone there?', 'Good to see you again!'), ('Is anyone there?', 'Hi there, how can I help?'), ('Hello', 'Hello!')]

# %%
# ===============================
# 1. Dataset mini (câu hỏi → câu trả lời)
# ===============================

import re
words = []
print(len(pairs))
for q, a in pairs:
    q_clean = re.sub(r'[^\w\s]', '', q.lower())
    a_clean = re.sub(r'[^\w\s]', '', a.lower())
    words.append((q_clean, a_clean))
# Tạo từ điển char → index và index → char
all_text = " ".join([q +" "+ a for q, a in words])
print(all_text)
lst=list(set(all_text.split(" ")))
lst.extend(['\t','\n'])
chars = sorted(lst)
print(chars)
char2idx = {c:i for i,c in enumerate(chars)}
idx2char = {i:c for i,c in enumerate(chars)}

num_chars = len(chars)
max_len_input = max(len(q_clean.split(" ")) for q_clean, _ in words)
max_len_target = max(len(a_clean.split(" ")) for _, a_clean in words)
print(max_len_input)
print(max_len_target)
# Out:
# 528
# hi hello hi good to see you again hi hi there how can i help how are you hello how are you good to see you again how are you hi there how can i help is anyone there hello is anyone there good to see you again is anyone there hi there how can i help hello hello hello good to see you again hello hi there how can i help good day hello good day good to see you again good day hi there how can i help whats up hello whats up good to see you again whats up hi there how can i help how are ya hello how are ya good to see you again how are ya hi there how can i help heyy hello heyy good to see you again heyy hi there how can i help whatsup hello whatsup good to see you again whatsup hi there how can i help    hello    good to see you again    hi there how can i help cya sad to see you go  cya talk to you later cya goodbye cya come back soon see you sad to see you go  see you talk to you later see you goodbye see you come back soon bye bye sad to see you go  bye bye talk to you later bye bye goodbye bye bye come back soon see you later sad to see you go  see you later talk to you later see you later goodbye see you later come back soon goodbye sad to see you go  goodbye talk to you later goodbye goodbye goodbye come back soon i am leaving sad to see you go  i am leaving talk to you later i am leaving goodbye i am leaving come back soon bye sad to see you go  bye talk to you later bye goodbye bye come back soon have a good day sad to see you go  have a good day talk to you later have a good day goodbye have a good day come back soon talk to you later sad to see you go  talk to you later talk to you later talk to you later goodbye talk to you later come back soon ttyl sad to see you go  ttyl talk to you later ttyl goodbye ttyl come back soon i got to go sad to see you go  i got to go talk to you later i got to go goodbye i got to go come back soon gtg sad to see you go  gtg talk to you later gtg goodbye gtg come back soon what is the name of your developers dinh quoc huy what is the name of your creators dinh quoc huy what is the name of the developers dinh quoc huy what is the name of the creators dinh quoc huy who created you dinh quoc huy your developers dinh quoc huy your creators dinh quoc huy who are your developers dinh quoc huy developers dinh quoc huy you are made by dinh quoc huy you are made by whom dinh quoc huy who created you dinh quoc huy who create you dinh quoc huy creators dinh quoc huy who made you dinh quoc huy who designed you dinh quoc huy name you can call me mind reader name im mind reader name i am a chatbot name i am your helper your name you can call me mind reader your name im mind reader your name i am a chatbot your name i am your helper do you have a name you can call me mind reader do you have a name im mind reader do you have a name i am a chatbot do you have a name i am your helper what are you called you can call me mind reader what are you called im mind reader what are you called i am a chatbot what are you called i am your helper what is your name you can call me mind reader what is your name im mind reader what is your name i am a chatbot what is your name i am your helper what should i call you you can call me mind reader what should i call you im mind reader what should i call you i am a chatbot what should i call you i am your helper whats your name you can call me mind reader whats your name im mind reader whats your name i am a chatbot whats your name i am your helper what are you you can call me mind reader what are you im mind reader what are you i am a chatbot what are you i am your helper who are you you can call me mind reader who are you im mind reader who are you i am a chatbot who are you i am your helper who is this you can call me mind reader who is this im mind reader who is this i am a chatbot who is this i am your helper what am i chatting to you can call me mind reader what am i chatting to im mind reader what am i chatting to i am a chatbot what am i chatting to i am your helper who ...
# ['', '\t', '\n', '04198045', '2', '60', '6pm', '8am', '8am5pm', 'a', 'about', 'ac', 'academic', 'activate', 'active', 'activities', 'add', 'address', 'admision', 'admission', 'after', 'again', 'against', 'aiml', 'all', 'allotment', 'allround', 'also', 'alupuri', 'am', 'an', 'and', 'answer', 'antiragging', 'any', 'anyone', 'anything', 'application', 'appreciated', 'appropriate', 'are', 'ask', 'ass', 'asshole', 'assist', 'at', 'attend', 'auditorium', 'automobile', 'available', 'average', 'back', 'be', 'between', 'big', 'bitch', 'book', 'books', 'boys', 'branch', 'branches', 'bring', 'building', 'by', 'bye', 'cafetaria', 'calendar', 'calender', 'call', 'called', 'campus', 'can', 'canteen', 'capacity', 'cases', 'casuals', 'ce', 'chatbot', 'chatting', 'chemical', 'circuler', 'civil', 'classes', 'classroom', 'classsoordinators', 'clean', 'clear', 'code', 'college', 'come', 'committe', 'committee', 'companies', 'comps', 'computer', 'conducted', 'connection', 'contact', 'courses', 'create', 'created', 'creators', 'cya', 'dates', 'day', 'days', 'decency', 'department', 'departments', 'designed', 'detail', 'details', 'developers', 'development', 'differ', 'different', 'differentso', 'dinh', 'direct', 'distance', 'do', 'document', 'documents', 'does', 'done', 'dress', 'dresscode', 'dumb', 'during', 'each', 'eat', 'else', 'encourages', 'end', 'engineering', 'engineeringchemical', 'enter', 'environment', 'event', 'events', 'exam', 'excellent', 'extc', 'facilities', 'facility', 'far', 'fee', 'fees', 'first', 'firstthat', 'floors', 'food', 'foods', 'for', 'fourth', 'franky', 'free', 'from', 'fuck', 'fucker', 'fully', 'functions', 'games', 'get', 'girls', 'give', 'given', 'glad', 'go', 'good', 'goodbye', 'got', 'government', 'gtg', 'guys', 'has', 'have', 'held', 'hell', 'hello', 'help', 'helped', 'helper', 'hence', 'here', 'heyy', 'hi', 'history', 'hod', 'hods', 'holiday', 'holidays', 'hostel', 'hours', 'how', 'huge', 'huy', 'i', 'idiot', 'if', 'im', 'in', 'incidents', 'info', 'information', 'infrastructure', 'intake', 'internet', 'is', 'it', 'its', 'job', 'join', 'juniors', 'k', 'kachori', 'khavsa', 'lab', 'labs', 'language', 'later', 'leaving', 'lecture', 'libraries', 'library', 'librarycanteen', 'librarytimings', 'like', 'list', 'located', 'location', 'locho', 'long', 'love', 'lowintermediate', 'made', 'maintaining', 'many', 'marry', 'max', 'maximum', 'may', 'me', 'mechanical', 'menu', 'mind', 'mondaysaturday', 'more', 'much', 'my', 'name', 'need', 'needed', 'next', 'nice', 'no', 'nonac', 'not', 'number', 'of', 'offer', 'offered', 'offers', 'office', 'ok', 'okay', 'okie', 'okk', 'on', 'one', 'online', 'only', 'open', 'operation', 'or', 'organised', 'our', 'own', 'package', 'per', 'phone', 'place', 'placement', 'please', 'practice', 'principal', 'principals', 'process', 'program', 'proud', 'provide', 'provided', 'provides', 'query', 'questions', 'quoc', 'ragging', 'reach', 'reader', 'recruitment', 'regarding', 'required', 'respective', 'richard', 'room', 'rules', 'sad', 'saturday', 'schedule', 'scholarship', 'scholarships', 'school', 'seat', 'seats', 'second', 'see', 'sem', 'semester', 'serve', 'servive', 'should', 'shut', 'size', 'smart', 'something', 'soon', 'spacious', 'specific', 'speed', 'sports', 'starts', 'strict', 'students', 'stundent', 'stupid', 'submitted', 'supported', 'syllabus', 'take', 'taken', 'taking', 'talk', 'tall', 'technology', 'telephone', 'tell', 'thaali', 'thank', 'thanks', 'that', 'the', 'them', 'then', 'there', 'these', 'thing', 'things', 'third', 'this', 'through', 'time', 'timetable', 'timing', 'to', 'total', 'try', 'ttyl', 'u', 'ultimo', 'uni', 'uniform', 'unis', 'university', 'universitys', 'univrsityuni', 'unversitys', 'up', 'use', 'uts', 'vacation', 'vacations', 'variety', 'various', 'visit', 'we', 'wear', 'webpage', 'website', 'welcome', 'well', 'what', 'whats', 'whatsup', 'whatv', 'when', 'where', 'wheres', 'which', 'who', 'whom', 'why', 'will', 'wise', 'with', 'work', 'working', 'would', 'xyz', 'ya', 'year ...
# 9
# 20

# %%
# ===============================
# 2. Prepare input/output data (one-hot encoding)
# ===============================
def encode_text(text, max_len):
    x = np.zeros((1, max_len, num_chars), dtype='float32')
    clean_text= re.sub(r'[^\w\s]', '', text.lower())
    for t, char in enumerate(list(clean_text.split(" "))):
        x[0, t, char2idx[char]] = 1.0
    return x

encoder_input_data = []
decoder_input_data = []
decoder_target_data = []

for q, a in pairs:
    # Add start and end tokens for decoder
    a_in = "\t " + a  # start token
    a_out = a + " \n" # end token
    
    enc = encode_text(q, max_len_input)
    dec_in = encode_text(a_in, max_len_target + 1)
    dec_out = encode_text(a_out, max_len_target + 1)
    
    encoder_input_data.append(enc)
    decoder_input_data.append(dec_in)
    decoder_target_data.append(dec_out)

encoder_input_data = np.vstack(encoder_input_data)
decoder_input_data = np.vstack(decoder_input_data)
decoder_target_data = np.vstack(decoder_target_data)

# %%
# ===============================
# 3. Build Seq2Seq model
# ===============================
latent_dim = 16
#input
encoder_inputs = Input(shape=(None, num_chars))
decoder_inputs = Input(shape=(None, num_chars))


# Encoder
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Decoder
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_chars, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# Out:
# 2025-09-12 15:42:58.923265: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-09-12 15:42:58.923299: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2025-09-12 15:42:58.923308: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2025-09-12 15:42:58.923346: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-09-12 15:42:58.923365: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# ===============================
# 4. Train model (rất nhanh vì dataset nhỏ)
# ===============================
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=1, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2686
# Epoch 2/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2581
# Epoch 3/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2568
# Epoch 4/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2574
# Epoch 5/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2655
# Epoch 6/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2520
# Epoch 7/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2551
# Epoch 8/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2517
# Epoch 9/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2517
# Epoch 10/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2581
# Epoch 11/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2750
# Epoch 12/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2674
# Epoch 13/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2579
# Epoch 14/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2497
# Epoch 15/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2476
# Epoch 16/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2500
# Epoch 17/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2628
# Epoch 18/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2531
# Epoch 19/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.3274
# Epoch 20/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2927
# Epoch 21/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2714
# Epoch 22/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2609
# Epoch 23/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2604
# Epoch 24/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2674
# Epoch 25/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2613
# Epoch 26/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2630
# Epoch 27/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2535
# Epoch 28/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2591
# Epoch 29/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3088
# Epoch 30/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2809
# Epoch 31/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2686
# Epoch 32/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2527
# Epoch 33/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2949
# Epoch 34/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2548
# Epoch 35/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2700
# Epoch 36/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3004
# Epoch 37/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2681
# Epoch 38/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2707
# Epoch 39/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2577
# Epoch 40/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2544
# Epoch 41/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2628
# Epoch 42/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2507
# Epoch 43/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2497
# Epoch 44/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2522
# Epoch 45/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2663
# Epoch 46/100
# 528/528 [==============================] - 4s 9ms/step - loss: 0.2563
# Epoch 47/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2527
# Epoch 48/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2540
# Epoch 49/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2513
# Epoch 50/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2713
# Epoch 51/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2628
# Epoch 52/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2624
# Epoch 53/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2487
# Epoch 54/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2508
# Epoch 55/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2476
# Epoch 56/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2569
# Epoch 57/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2612
# Epoch 58/100
# 528/528 [==============================] - 4s 9ms/step - loss: 0.2739
# Epoch 59/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2542
# Epoch 60/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2467
# Epoch 61/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2463
# Epoch 62/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2496
# Epoch 63/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2495
# Epoch 64/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2570
# Epoch 65/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2575
# Epoch 66/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2806
# Epoch 67/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2589
# Epoch 68/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2474
# Epoch 69/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2666
# Epoch 70/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2538
# Epoch 71/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2851
# Epoch 72/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2647
# Epoch 73/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2720
# Epoch 74/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2617
# Epoch 75/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2986
# Epoch 76/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2596
# Epoch 77/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2505
# Epoch 78/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2806
# Epoch 79/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2522
# Epoch 80/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2491
# Epoch 81/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2513
# Epoch 82/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2486
# Epoch 83/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2508
# Epoch 84/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2559
# Epoch 85/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2586
# Epoch 86/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2651
# Epoch 87/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2616
# Epoch 88/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2655
# Epoch 89/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2635
# Epoch 90/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2623
# Epoch 91/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2649
# Epoch 92/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2518
# Epoch 93/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2665
# Epoch 94/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2515
# Epoch 95/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2869
# Epoch 96/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2648
# Epoch 97/100
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2653
# Epoch 98/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2538
# Epoch 99/100
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2550
# Epoch 100/100
# 528/528 [==============================] - 4s 8ms/step - loss: 0.2487

# %%
# ===============================
# 5. Inference (decode)
# ===============================
# Encoder model
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs_inf, state_h_inf, state_c_inf = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states_inf = [state_h_inf, state_c_inf]
decoder_outputs_inf = decoder_dense(decoder_outputs_inf)
decoder_model = Model([decoder_inputs] + decoder_states_inputs,
                      [decoder_outputs_inf] + decoder_states_inf)

# Hàm giải mã
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)
    
    target_seq = np.zeros((1, 1, num_chars))
    target_seq[0, 0, char2idx["\t"]] = 1.0
    
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = idx2char[sampled_token_index]
        
        if sampled_char == "\n" or len(decoded_sentence.split(" ")) >= max_len_target-1:
            stop_condition = True
            decoded_sentence += sampled_char
        else:
            decoded_sentence += sampled_char+" "
        
        target_seq = np.zeros((1, 1, num_chars))
        target_seq[0, 0, sampled_token_index] = 1.0
        states_value = [h, c]
    
    return decoded_sentence.strip()

encoder_model.save("encoder_model.h5")
decoder_model.save("decoder_model.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# ===============================
# 6. Demo chatbot
# ===============================
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye!")
        break
    seq = encode_text(user_input, max_len_input)
    response = decode_sequence(seq)
    print("Chatbot:", response)
# Out:
# 1/1 [==============================] - 0s 128ms/step
# WARNING:tensorflow:5 out of the last 32 calls to <function Model.make_predict_function.<locals>.predict_function at 0x31495cdc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Chatbot: hi there how can i menu
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Chatbot: good to see you again
# Chatbot: Goodbye!

# %%
import os

# Tạo thư mục assets nếu chưa có
os.makedirs("assets", exist_ok=True)

# Lưu char2idx và idx2char
with open("assets/char2idx.json", "w", encoding="utf-8") as f:
    json.dump(char2idx, f, ensure_ascii=False, indent=2)

# Lưu idx2char (chuyển key thành string để JSON đọc được)
idx2char_str = {str(k): v for k, v in idx2char.items()}
with open("assets/idx2char.json", "w", encoding="utf-8") as f:
    json.dump(idx2char_str, f, ensure_ascii=False, indent=2)

# Lưu config (số chiều, max_len…)
config = {
    "num_chars": num_chars,
    "max_len_input": max_len_input,
    "max_len_target": max_len_target,
    "latent_dim": latent_dim
}
with open("assets/config.json", "w", encoding="utf-8") as f:
    json.dump(config, f, ensure_ascii=False, indent=2)

print("Saved assets to assets/")
# Out:
# ✅ Saved assets to assets/
